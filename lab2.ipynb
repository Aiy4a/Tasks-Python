# %%
stringg = "I love Python.Python is fun!"
print(stringg.replace("Python" , "Programming"))
# Out:
# I love Programming.Programming is fun!

# %%
string2 = "The quick brown fox jumps over the lazy dog. The fox is clever!"
print(string2.count("fox"))
# Out:
# 2

# %%
string3 = "Python programming is fun!"
print(string3.startswith("Python"))
print(string3.startswith("python"))
# Out:
# True
# False

# %%
string4 = "123abc"
print(string4.isdigit())  
print(string4.isalpha()) 
print(string4.isalnum())
# Out:
# False
# False
# True
