# %%
def favorite_book(book_title):
    """Displays the favorite book"""
    print(f"One of my favorite books is {book_title}")


favorite_book("Alice in Wonderland")
# Out:
# One of my favorite books is Alice in Wonderland

# %%
help(favorite_book)
# Out:
# Help on function favorite_book in module __main__:
#
# favorite_book(book_title)
#     Displays the favorite book

# %%
def mean_calc(num1 , num2 , num3):
    mean_value = (num1 + num2 + num3) / 3
    return mean_value

mean_value = mean_calc(5,3,1)
print(f"{mean_value}")
# Out:
# 3.0
